# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("Simulation_data_1.csv")
display(df)
# Out:
# C:\Users\frede\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.2' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#       acc_x  acc_y     acc_z  vel_x  vel_y     vel_z  ang_acc_roll  \
# 0       0.0    0.0  0.000000    0.0    0.0  0.000000           0.0
# 1       0.0    0.0  0.000000    0.0    0.0  0.000000           0.0
# 2       0.0    0.0  0.000000    0.0    0.0  0.000000           0.0
# 3       0.0    0.0  0.000000    0.0    0.0  0.000000           0.0
# 4       0.0    0.0  0.000000    0.0    0.0  0.000000           0.0
# ...     ...    ...       ...    ...    ...       ...           ...
# 6195    0.0    0.0  0.001058    0.0    0.0 -0.030572           0.0
# 6196    0.0    0.0  0.001059    0.0    0.0 -0.030567           0.0
# 6197    0.0    0.0  0.001058    0.0    0.0 -0.030562           0.0
# 6198    0.0    0.0  0.001058    0.0    0.0 -0.030556           0.0
# 6199    0.0    0.0  0.001056    0.0    0.0 -0.030551           0.0
#
#       ang_acc_pitch  ang_acc_yaw  ang_vel_roll  ...        yaw        u1  \
# 0               0.0          0.0           0.0  ... -19.999989  0.000000
# 1               0.0          0.0           0.0  ... -19.999989  0.000000
# 2               0.0          0.0           0.0  ... -19.999989  0.000000
# 3               0.0          0.0           0.0  ... -19.999989  0.000000
# 4               0.0          0.0           0.0  ... -19.999989  0.000000
# ...             ...          ...           ...  ...        ...       ...
# 6195            0.0          0.0           0.0  ... -20.002058 -0.426160
# 6196            0.0          0.0           0.0  ... -20.002058 -0.426087
# 6197            0.0          0.0           0.0  ... -20.002058 -0.426014
# 6198            0.0          0.0           0.0  ... -20.002058 -0.425941
# 6199            0.0          0.0           0.0  ... -20.002058 -0.425868
#
#             u2        u3        x1        x2        x3   x4        x5  \
# 0     0.000000  0.000000  1.340000  0.000000  0.000000  0.0  0.000000
# 1     0.000000  0.000000  1.340000  0.000000  0.000000  0.0  0.000000
# 2     0.000000  0.000000  1.340000  0.000000  0.000000  0.0  0.000000
# 3     0.000000  0.000000  1.340000  0.000000  0.000000  0.0  0.000000
# 4     0.000000  0.000000  1.340000  0.000000  0.000000  0.0  0.000000
# ...        ...       ...       ...       ...       ...  ...       ...
# 6195 -0.424910  0.060159  0.280222 -0.030572 -0.708465  0.0 -0.093259
# 6196 -0.424837  0.060117  0.280071 -0.030567 -0.708465  0.0 -0.093259
# 6197 -0.424763  0.060075  0.279919 -0.030562 -0.708465  0.0 -0.093259
# 6198 -0.424690  0.060033  0.279768 -0.030556 -0.708465  0.0 -0.093259
# 6199 -0.424617  0.059991  0.279619 -0.030551 -0.708465  0.0 -0.093171
#
#             x6
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# ...        ...
# 6195  0.002547
# 6196  0.002575
# 6197  0.002603
# 6198  0.002632
# 6199  0.002660
#
# [6200 rows x 27 columns]

# %%
t1 = np.arange(0, len(df["x"]))/200
plt.plot(t1,df["u1"], label = "u1")
plt.plot(t1,df["u2"], label = "u2")
plt.plot(t1,df["u3"], label = "u3")
plt.legend()

# %%
plt.plot(t1,df["roll"])
